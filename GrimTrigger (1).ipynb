# %%
import matplotlib.pyplot as plt

#We will model the functions of the payoffs of collaborating and defecting as per the algebra done before

def interactions(p_interacting, leader, op):
    # p_interacting = probability of the game continuing
    # leader= payoff for a leader
    # op=payoff for an operative which is equal to 1

  
    n_iter = 500 # number of intercations
    time_step = .03
    
    # payoffs for both cooperating, and not cooperating from the perspective of one agent:
    cc = leader
    n = 1
    
    collaborate=[]
    defect=[]
#Modeling the functions over time and appending the payoffs to a list    
    for i in range(n_iter):
        # expected payoffs given n number of iterations as long as they are less than 500
        pay_collab=(p_collab**n)*(cc)
        pay_notcollab=n

        
        collaborate.append(pay_collab)
        defect.append(pay_notcollab)
#This is the payoff for defecting because you get an operative every time, hence it is the same as every time you defect
        n+=1
 #This is the code that plots the functions of the payoffs of collaborating and defecting
    plt.plot(range(n_iter), collaborate, label='Payoff of collaborating')
    plt.plot(range(n_iter), defect, label='Payoff of defecting')
    plt.ylabel('Payoffs')
    plt.xlabel('Number of interactions')
    plt.legend()
    plt.show()

# %%
interactions(0.99, 1000, 1)
